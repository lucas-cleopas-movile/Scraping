# %%
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError

from bs4 import BeautifulSoup

# %%
url = 'https://globoplay.globo.com/categorias/filmes/'
headers = {'User-Agent': 'Chrome/76.0.3809.100'}

try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    html = response.read()

except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e:
    print(e.reason)

# %%
def handle_html(html):
    html = html.decode('utf-8')
    return " ".join(html.split()).replace('> <', '><')

# %%
html = handle_html(html)

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- ____ _ _ _ _ / __ \ (_) | | (_) | | | | |_ _ _ ___| | _____ _| |_ _____ _ __ | | | | | | | |/ __| |/ / __| | \ \ / / _ \ '__| | |__| | |_| | | (__| <\__ \ | |\ V / __/ | \___\_\\__,_|_|\___|_|\_\___/_|_| \_/ \___|_| -->
# <html lang="pt-br">
#  <head>
#   <!-- First input delay polyfill -->
#   <script>
#    !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);
#   </script>
#   <script>
#    !function(){if('PerformanceLongTaskTiming' in window){var g=window.__tti={e:[]}; g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())}); g.o.observe({entryTypes:['longtask']})}}();
#   </script>
#   <title data-react-helmet="true">
#    Assistir Filmes online no Globoplay
#   </title>
#   <meta charset="utf-8" data-react-helmet="true"/>
#   <meta content="IE=edge" data-react-helmet="true" http-equiv="X-UA-Compatible"/>
#   <meta content="Assistir Filmes online no Globoplay" data-react-helmet="true" property="og:title"/>
#   <meta content="Assistir Filmes online no Globoplay" data-react-helmet="true" name="twitter:title"/>
#   <meta content="https://globoplay.globo.com/categorias/filmes/" data-react-helmet="true" property="og:url"/>
#   <meta content="Assistir Filmes online quando e onde quiser pelo Globoplay." data-react-helmet="true" key="description" name="description"/>
#   <meta content="Assistir Filmes online quando e onde quiser pelo Globoplay." data-react-helmet="true" property="og:description"/>
#   <meta content="Assistir Filmes online quando e onde quiser pelo Globoplay." data-react-helmet="true" name="twitter:description"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/home-share-e7d30f4.png" data-react-helmet="true" property="og:image"/>
#   <meta content="Globoplay" data-react-helmet="true" property="og:image:alt"/>
#   <meta content="Globoplay" data-react-helmet="true" property="og:site_name"/>
#   <meta content="289255557788943" data-react-helmet="true" property="fb:app_id"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/home-share-e7d30f4.png" data-react-helmet="true" name="twitter:image"/>
#   <meta content="@globoplay" data-react-helmet="true" name="twitter:site"/>
#   <meta content="summary_large_image" data-react-helmet="true" name="twitter:card"/>
#   <meta content="app-id=536321738" data-react-helmet="true" name="apple-itunes-app"/>
#   <meta content="app-id=com.globo.globotv" data-react-helmet="true" name="google-play-app"/>
#   <meta content="width=device-width, initial-scale=1.0" data-react-helmet="true" name="viewport"/>
#   <meta content="yes" data-react-helmet="true" name="mobile-web-app-capable"/>
#   <meta content="yes" data-react-helmet="true" name="apple-mobile-web-app-capable"/>
#   <meta content="black" data-react-helmet="true" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="telephone=no" data-react-helmet="true" name="format-detection"/>
#   <meta content="Globoplay" data-react-helmet="true" name="application-name"/>
#   <meta content="#101010" data-react-helmet="true" name="msapplication-TileColor"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/mstile-144x144-3ff095f.png" data-react-helmet="true" name="msapplication-TileImage"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/mstile-70x70-abdcdf3.png" data-react-helmet="true" name="msapplication-square70x70logo"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/mstile-150x150-2c8cce5.png" data-react-helmet="true" name="msapplication-square150x150logo"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/mstile-310x150-c33d7dd.png" data-react-helmet="true" name="msapplication-wide310x150logo"/>
#   <meta content="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/mstile-310x310-81be642.png" data-react-helmet="true" name="msapplication-square310x310logo"/>
#   <meta content="#101010" data-react-helmet="true" name="theme-color"/>
#   <meta content="OG6JW8pGkWtxxgPuFkATBDhc61RF0E1ZK7mobGGqSuc" data-react-helmet="true" name="google-site-verification"/>
#   <meta content="website" data-react-helmet="true" property="og:type"/>
#   <link data-react-helmet="true" href="https://globoplay.globo.com/categorias/filmes/" rel="canonical"/>
#   <link data-react-helmet="true" href="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/favicon-9805031.ico" rel="shortcut icon"/>
#   <link data-react-helmet="true" href="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/apple-touch-icon-bcc7880.png" rel="apple-touch-icon"/>
#   <link data-react-helmet="true" href="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/android-chrome-192x192-d0bcbc1.png" rel="android-chrome-192x192"/>
#   <link data-react-helmet="true" href="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/android-chrome-512x512-b9f8a17.png" rel="android-chrome-512x512"/>
#   <link crossorigin="anonymous" href="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/app-vendor-bundle-acb2492.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/app-client-bundle-592e21b.css" rel="stylesheet"/>
#   <link as="font" crossorigin="" href="https://s.glbimg.com/gl/ba/fonts/opensans-regular-webfont.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="https://s.glbimg.com/gl/ba/fonts/opensans-light-webfont.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="https://s.glbimg.com/gl/ba/fonts/opensans-semibold-webfont.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="https://s.glbimg.com/gl/ba/fonts/opensans-bold-webfont.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="https://s.glbimg.com/gl/ba/fonts/globofutura-bold-webfont.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="https://s.glbimg.com/gl/ba/fonts/globofutura-medium-webfont.woff" rel="preload"/>
#   <link href="/pwa-manifest.json" rel="manifest"/>
#   <script data-react-helmet="true" type="application/ld+json">
#    {"@context":"http://schema.org","type":"WebPage","name":"Assistir Filmes online no Globoplay","description":"Assistir Filmes online quando e onde quiser pelo Globoplay.","url":"https://globoplay.globo.com/categorias/filmes/","image":"https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/home-share-e7d30f4.png"}
#   </script>
#   <script defer="" src="https://s.glbimg.com/pc/ca/cadun.js">
#   </script>
#   <script defer="" src="https://p.glbimg.com/api/stable/api.min.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/app-chunk-manifest-bundle-a8f5411.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/app-vendor-bundle-450de87.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://s3.glbimg.com/v1/AUTH_2caf29d99e86401197555831070efae8/secure/app-client-bundle-d10a7f3.js">
#   </script>
#  </head>
#  <body>
#   <div id="app">
#    <div>
#     <div class="app-layout">
#      <div aria-hidden="false" class="application-controller__layout">
#       <div class="header__placeholder">
#       </div>
#       <header class="header">
#        <div class="header__menu-icon">
#         <button aria-label="botao-menu" class="menu-button" id="menu-button">
#          <svg class="menu-icon" enable-background="new 0 0 512 512" height="512px" version="1.1" viewbox="0 0 512 512" width="512px" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#           <path d="M416,224H96c-17.673,0-32,14.327-32,32s14.327,32,32,32h320 c17.673,0,32-14.327, 32-32S433.673,224,416,224z M416,352H96c-17.673,0-32,14.327-32,32s14.327,32,32,32h320 c17.673,0,32-14.327,32-32S433.673,352,416,352z M96,160h320c17.673,0,32-14.327, 32-32s-14.327-32-32-32H96 c-17.673,0-32,14.327-32,32S78.327,160,96,160z">
#           </path>
#          </svg>
#          <span>
#          </span>
#         </button>
#         <div>
#          <div class="menu__container menu__container--close">
#           <span class="menu__close">
#            <svg class="close-icon" enable-background="new 0 0 512 512" height="100%" version="1.1" viewbox="0 0 512 512" width="100%" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#             <path d="M512,51.75L460.25,0L256,204.25L51.75,0L0,51.75L204.25,256L0,460.25L51.75,512L256, 307.75L460.25,512L512,460.25 L307.75,256L512,51.75z">
#             </path>
#            </svg>
#           </span>
#           <div class="menu__content">
#            <span>
#             <div>
#              <div class="menu-content">
#               <div class="menu-slot">
#                <button class="menu-item" tabindex="0">
#                 <span class="menu-icon-widget">
#                  <svg class="" height="17" width="20" xmlns="http://www.w3.org/2000/svg">
#                   <g fill="none" fill-rule="evenodd" transform="translate(-2 -4)">
#                    <path d="M10 21v-6h4v6h5v-8h3L12 4 2 13h3v8z">
#                    </path>
#                   </g>
#                  </svg>
#                 </span>
#                 Início
#                </button>
#                <button class="menu-item" tabindex="0">
#                 <span class="menu-icon-widget">
#                  <div class="menu-notifications-icon__container">
#                   <svg class="" height="20" width="16" xmlns="http://www.w3.org/2000/svg">
#                    <g fill="none" fill-rule="evenodd" transform="translate(-4 -2)">
#                     <path d="M12 21.5c1.1 0 2-.9 2-2h-4a2 2 0 0 0 2 2zm6-6v-5c0-3.07-1.64-5.64-4.5-6.32V3.5c0-.83-.67-1.5-1.5-1.5s-1.5.67-1.5 1.5v.68C7.63 4.86 6 7.42 6 10.5v5l-2 2v1h16v-1l-2-2z">
#                     </path>
#                    </g>
#                   </svg>
#                   <span>
#                   </span>
#                  </div>
#                 </span>
#                 Novidades
#                 <span class="expandable-item__arrow">
#                  <svg class="arrow-icon right" enable-background="new 0 0 512 512" height="512px" preserveaspectratio="xMinYMin meet" version="1.1" viewbox="0 0 512 512" width="512px" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                   <g>
#                    <g transform="translate(261.928932, 262.000000) rotate(45.000000) translate(-261.928932, -262.000000) translate(76.928932, 77.000000)">
#                     <g>
#                      <path d="M146.537,223.463l277.301,0c11.343,0,20.537,9.197,20.536,20.541l0.001, 30.81 c-0.001,11.345-9.197,20.541-20.539,20.541l-328.654,0c-5.671, 0-10.805-2.299-14.521-6.015 c-3.718-3.719-6.017-8.853-6.017-14.523l0-328.654c0.001-11.342, 9.197-20.538,20.541-20.539l30.809,0 c11.344,0,20.541,9.197,20.541,20.537l-0.001, 277.301L146.537,223.463z">
#                      </path>
#                     </g>
#                     <g>
#                      <path d="M146.537,223.463l277.301,0c11.343,0,20.537,9.197,20.536,20.541l0.001, 30.81 c-0.001,11.345-9.197,20.541-20.539,20.541l-328.654,0c-5.671, 0-10.805-2.299-14.521-6.015 c-3.718-3.719-6.017-8.853-6.017-14.523l0-328.654c0.001-11.342, 9.197-20.538,20.541-20.539l30.809,0 c11.344,0,20.541,9.197,20.541,20.537l-0.001, 277.301L146.537,223.463z">
#                      </path>
#                     </g>
#                    </g>
#                   </g>
#                  </svg>
#                 </span>
#                </button>
#               </div>
#               <div class="menu-slot">
#                <a aria-label="Ir para programação ao vivo" class="menu-item-link" href="/agora-na-tv/">
#                 <button class="menu-item" tabindex="0">
#                  <span class="menu-icon-widget">
#                   <svg class="" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#                    <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#                     <g transform="translate(2.000000, 4.000000)">
#                      <path d="M12.3809,8.0708 C12.3809,6.7568 11.3149,5.6898 9.9999,5.6898 C8.6859,5.6898 7.6189,6.7568 7.6189,8.0708 C7.6189,9.3848 8.6859,10.4518 9.9999,10.4518 C11.3149,10.4518 12.3809,9.3848 12.3809,8.0708" fill="#CCCCCC" id="Fill-1">
#                      </path>
#                      <path d="M6.9697,11.1011 C6.1947,10.3261 5.7147,9.2541 5.7147,8.0711 C5.7147,6.8871 6.1947,5.8161 6.9697,5.0401 L5.6227,3.6931 C4.5027,4.8141 3.8097,6.3611 3.8097,8.0711 C3.8097,9.7801 4.5027,11.3281 5.6227,12.4481 L6.9697,11.1011 Z" fill="#CCCCCC" id="Fill-3">
#                      </path>
#                      <g transform="translate(0.000000, 0.141600)">
#                       <path d="M4.2759,13.6533 C2.8109,12.1883 1.9049,10.1643 1.9049,7.9293 C1.9049,5.6943 2.8109,3.6703 4.2759,2.2053 L2.9289,0.8583 C1.1189,2.6683 -0.0001,5.1683 -0.0001,7.9293 C-0.0001,10.6903 1.1189,13.1903 2.9289,15.0003 L4.2759,13.6533 Z" fill="#CCCCCC" id="Fill-5" mask="url(#mask-2)">
#                       </path>
#                      </g>
#                      <path d="M13.0303,5.0405 C13.8053,5.8155 14.2853,6.8875 14.2853,8.0705 C14.2853,9.2545 13.8053,10.3255 13.0303,11.1015 L14.3773,12.4485 C15.4973,11.3275 16.1903,9.7805 16.1903,8.0705 C16.1903,6.3615 15.4973,4.8135 14.3773,3.6935 L13.0303,5.0405 Z" fill="#CCCCCC" id="Fill-8">
#                      </path>
#                      <g transform="translate(15.000000, 0.141600)">
#                       <path d="M0.7241,2.2051 C2.1891,3.6701 3.0951,5.6941 3.0951,7.9291 C3.0951,10.1641 2.1891,12.1881 0.7241,13.6531 L2.0711,15.0001 C3.8811,13.1901 5.0001,10.6901 5.0001,7.9291 C5.0001,5.1681 3.8811,2.6681 2.0711,0.8581 L0.7241,2.2051 Z" fill="#CCCCCC" id="Fill-10" mask="url(#mask-4)">
#                       </path>
#                      </g>
#                     </g>
#                    </g>
#                   </svg>
#                  </span>
#                  Agora na TV
#                 </button>
#                </a>
#                <a aria-label="Ver categorias" class="menu-item-link" href="/categorias/">
#                 <button class="menu-item" tabindex="0">
#                  <span class="menu-icon-widget">
#                   <svg class="" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
#                    <g fill="none" fill-rule="evenodd" transform="translate(-2 -2)">
#                     <path d="M20 8H4V6h16v2zm-2-6H6v2h12V2zm4 10v8c0 1.1-.9 2-2 2H4c-1.1 0-2-.9-2-2v-8c0-1.1.9-2 2-2h16c1.1 0 2 .9 2 2z">
#                     </path>
#                    </g>
#                   </svg>
#                  </span>
#                  Explore
#                 </button>
#                </a>
#               </div>
#               <div class="menu-slot">
#                <a aria-label="Ir para as configurações do usuário" class="menu-item-link" href="/configuracoes/">
#                 <button class="menu-item" tabindex="0">
#                  <span class="menu-icon-widget">
#                   <svg class="" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
#                    <g fill="none" fill-rule="evenodd" transform="translate(-2 -2)">
#                     <path d="M19.64 12.98c.042-.32.073-.64.073-.98 0-.34-.031-.66-.072-.98l2.169-1.65a.495.495 0 0 0 .123-.64l-2.056-3.46a.524.524 0 0 0-.627-.22l-2.56 1c-.534-.4-1.11-.73-1.737-.98l-.39-2.65a.497.497 0 0 0-.505-.42H9.946a.497.497 0 0 0-.504.42l-.39 2.65c-.627.25-1.203.59-1.738.98l-2.56-1a.508.508 0 0 0-.627.22L2.071 8.73a.484.484 0 0 0 .124.64l2.169 1.65c-.041.32-.072.65-.072.98 0 .33.03.66.072.98l-2.17 1.65a.495.495 0 0 0-.123.64l2.056 3.46c.124.22.401.3.627.22l2.56-1c.535.4 1.11.73 1.738.98l.39 2.65c.031.24.247.42.504.42h4.112c.257 0 .473-.18.504-.42l.39-2.65a7.955 7.955 0 0 0 1.738-.98l2.56 1c.236.09.504 0 .627-.22l2.056-3.46a.495.495 0 0 0-.123-.64l-2.17-1.65zm-7.638 2.52c-1.984 0-3.598-1.57-3.598-3.5s1.614-3.5 3.598-3.5c1.984 0 3.598 1.57 3.598 3.5s-1.614 3.5-3.598 3.5z">
#                     </path>
#                    </g>
#                   </svg>
#                  </span>
#                  Configurações
#                 </button>
#                </a>
#                <a aria-label="Ir para a central de ajuda" class="menu-item-link" href="http://centraldeajuda.globo.com/Globoplay/" target="blank">
#                 <button class="menu-item" tabindex="-1">
#                  <span class="menu-icon-widget">
#                   <svg class="" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
#                    <g fill="none" fill-rule="evenodd" transform="translate(-2 -2)">
#                     <path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm1 17h-2v-2h2v2zm2.07-7.75l-.9.92C13.45 12.9 13 13.5 13 15h-2v-.5c0-1.1.45-2.1 1.17-2.83l1.24-1.26c.37-.36.59-.86.59-1.41 0-1.1-.9-2-2-2s-2 .9-2 2H8c0-2.21 1.79-4 4-4s4 1.79 4 4c0 .88-.36 1.68-.93 2.25z">
#                     </path>
#                    </g>
#                   </svg>
#                  </span>
#                  Ajuda
#                 </button>
#                </a>
#                <a aria-label="Mais sobre o Globoplay" class="menu-item-link" target="blank">
#                 <button class="menu-item" tabindex="-1">
#                  <span class="menu-icon-widget">
#                   <svg class="" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
#                    <g fill="none" fill-rule="evenodd" transform="translate(-2 -2)">
#                     <path d="M11 17h2v-6h-2v6zm1-15C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8zM11 9h2V7h-2v2z">
#                     </path>
#                    </g>
#                   </svg>
#                  </span>
#                  Sobre
#                 </button>
#                </a>
#               </div>
#              </div>
#             </div>
#            </span>
#           </div>
#           <div class="menu__background">
#           </div>
#          </div>
#         </div>
#        </div>
#        <a aria-label="Voltar para a home" class="header__logo" href="/">
#         <svg class="product-logo-icon" fill="none" height="128" viewbox="0 0 588 128" width="588" xmlns="http://www.w3.org/2000/svg">
#          <g clip-path="url(#clip0)">
#           <path d="M572.208 29.626c-2.218 0-3.545.892-4.141 2.812l-13.894 40.444-15.968-40.444c-.739-1.928-1.924-2.812-3.99-2.812h-13.449c-2.662 0-3.696 1.633-2.511 4.15L545.748 96l-2.218 4.74c-3.402 7.408-6.795 10.22-10.197 10.22-1.924 0-3.99-.589-5.914-1.481-2.066-1.036-3.847-.741-4.88 1.33l-3.847 7.408c-.891 1.777-.74 3.553 1.033 4.892 3.545 2.812 7.837 4.891 13.751 4.891 13.154 0 20.84-9.774 27.938-27.85l26.166-66.374c1.033-2.517.151-4.15-2.512-4.15h-12.86zM17.59 63.848c0-10.96 7.837-18.226 17.144-18.226 9.316 0 17.002 7.257 17.002 18.227 0 10.818-7.686 18.218-17.002 18.218-9.307.008-17.144-7.4-17.144-18.218zM0 64c0 20.146 14.633 34.071 33.113 34.071 8.274 0 14.633-3.856 18.329-7.855-.152 14.077-7.544 20.441-20.253 20.441-6.795 0-13.154-2.071-20.546-6.811-1.924-1.33-4.141-.892-5.175 1.187l-4.435 8.739C0 115.843.294 117.771 2.36 119.11c9.165 5.927 19.959 8.89 29.266 8.89 24.394 0 37.842-13.184 37.842-43.56V33.188c0-2.222-1.327-3.553-3.545-3.553H55.877c-2.218 0-3.545 1.33-3.545 3.553v3.856c-3.99-4.892-11.382-8.596-18.774-8.596C15.523 28.447 0 43.854 0 64zm122.833 0c0-10.515 7.686-18.227 17.145-18.227 9.458 0 17.144 7.703 17.144 18.227 0 10.515-7.686 18.218-17.144 18.218-9.45 0-17.145-7.703-17.145-18.218zm-17.883 0c0 20.593 15.666 35.553 35.036 35.553 19.068 0 35.036-14.96 35.036-35.553 0-20.593-15.666-35.553-35.036-35.553-19.068 0-35.036 14.96-35.036 35.553zm172.947 0c0-10.515 7.686-18.227 17.145-18.227 9.458 0 17.144 7.703 17.144 18.227 0 10.515-7.686 18.218-17.144 18.218-9.459 0-17.145-7.703-17.145-18.218zm-17.883 0c0 20.593 15.666 35.553 35.036 35.553 19.068 0 35.036-14.96 35.036-35.553 0-20.593-15.666-35.553-35.036-35.553-19.068 0-35.036 14.96-35.036 35.553zm96.079 0c0-10.818 7.686-18.227 16.85-18.227 9.165 0 16.851 7.409 16.851 18.227 0 10.961-7.686 18.218-16.851 18.218-9.164 0-16.85-7.257-16.85-18.218zm-.739-26.814v-3.999c0-2.222-1.328-3.553-3.545-3.553h-9.904c-2.217 0-3.545 1.33-3.545 3.553v90.073c0 2.223 1.328 3.553 3.545 3.553h10.937c2.218 0 3.545-1.33 3.545-3.553V91.706c4.284 4.445 11.231 7.855 18.48 7.855 18.035 0 32.819-15.406 32.819-35.553 0-20.146-15.078-35.552-32.668-35.552-8.282-.009-15.229 3.544-19.664 8.73zM460.303 64c0-10.961 7.686-18.227 16.851-18.227 9.164 0 16.85 7.257 16.85 18.227 0 10.818-7.686 18.218-16.85 18.218-9.156 0-16.851-7.408-16.851-18.218zm-17.883 0c0 20.146 15.078 35.553 32.667 35.553 8.274 0 15.229-3.553 19.656-8.739v3.999c0 2.222 1.327 3.553 3.545 3.553h9.912c2.218 0 3.545-1.33 3.545-3.553V33.187c0-2.222-1.327-3.553-3.545-3.553h-9.904c-2.217 0-3.544 1.33-3.544 3.553v4.294c-4.142-5.035-11.676-9.034-19.514-9.034-18.034 0-32.818 15.407-32.818 35.553zm-241.383 0c0-10.818 7.686-18.227 16.851-18.227 9.164 0 16.85 7.409 16.85 18.227 0 10.961-7.686 18.218-16.85 18.218-9.165 0-16.851-7.257-16.851-18.218zM186.841 1.33c-2.217 0-3.545 1.33-3.545 3.553v89.93c0 2.222 1.328 3.553 3.545 3.553h9.904c2.217 0 3.545-1.33 3.545-3.553v-3.856c4.284 4.892 12.272 8.596 20.101 8.596 17.295 0 32.222-15.701 32.222-35.553 0-20.146-15.078-35.553-32.667-35.553-7.098 0-14.045 3.115-18.623 7.855V4.892c0-2.223-1.327-3.553-3.545-3.553h-10.937V1.33zm232.672 0c-2.218 0-3.545 1.33-3.545 3.553v89.93c0 2.222 1.327 3.553 3.545 3.553h11.088c2.217 0 3.545-1.33 3.545-3.553V4.891c0-2.222-1.328-3.552-3.545-3.552h-11.088V1.33zM78.641 5.48v88.744c0 4.74 2.957 6.667 7.24 4.74l5.62-2.518c3.545-1.633 5.175-3.999 5.175-7.855V11.113c0-3.856-1.63-6.222-5.175-7.855L85.881.741C84.774.244 83.749 0 82.85 0c-2.587 0-4.208 1.97-4.208 5.48z" fill="url(#paint0_linear)">
#           </path>
#          </g>
#          <defs>
#           <lineargradient gradientunits="userSpaceOnUse" id="paint0_linear" x1="255.571" x2="426.433" y1="35.427" y2="205.906">
#            <stop stop-color="#FB0234">
#            </stop>
#            <stop offset="1" stop-color="#FF9101">
#            </stop>
#           </lineargradient>
#           <clippath id="clip0">
#            <path d="M0 0H588V128H0z" fill="#fff">
#            </path>
#           </clippath>
#          </defs>
#         </svg>
#        </a>
#        <nav class="header__items">
#         <a aria-label="Ir para programação ao vivo" class="link-item" href="/agora-na-tv/">
#          <nav class="header-item false">
#           Agora na TV
#          </nav>
#         </a>
#         <a aria-label="Ir para Novelas" class="link-item" href="/categorias/novelas/">
#          <nav class="header-item false">
#           Novelas
#          </nav>
#         </a>
#         <a aria-label="Ir para Séries" class="link-item" href="/categorias/series/">
#          <nav class="header-item false">
#           Séries
#          </nav>
#         </a>
#         <a aria-label="Ir para Filmes" class="link-item" href="/categorias/filmes/">
#          <nav class="header-item header-item__active">
#           Filmes
#          </nav>
#         </a>
#         <a aria-label="Ir para Infantil" class="link-item" href="/categorias/infantil/">
#          <nav class="header-item false">
#           Infantil
#          </nav>
#         </a>
#         <a aria-label="Ir para exploração de conteúdo agrupados por categorias e canais" class="link-item" href="/categorias/">
#          <nav class="header-item false">
#           Explore
#          </nav>
#         </a>
#        </nav>
#        <div class="toolbar__container">
#         <a aria-label="Ir para busca de itens" class="toolbar__search-bar" href="/busca/">
#          <span class="toolbar__search-icon">
#           <svg class="" height="18" width="18" xmlns="http://www.w3.org/2000/svg">
#            <g fill="none" fill-rule="evenodd" transform="translate(-3 -3)">
#             <path d="M15.5 14h-.79l-.28-.27A6.471 6.471 0 0 0 16 9.5 6.5 6.5 0 1 0 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z">
#             </path>
#            </g>
#           </svg>
#          </span>
#          <span class="toolbar__search-text">
#           Busca
#          </span>
#         </a>
#         <div class="toolbar__user-area">
#          <div class="user_avatar_toggle">
#           <div class="user_avatar_toggle__picture">
#            <button aria-label="botao-avatar" class="avatar-button" id="avatar-button">
#             <div class="avatar">
#              <div class="avatar__anonymous-default">
#               <svg class="user-picture-icon" height="40" width="40" xmlns="http://www.w3.org/2000/svg">
#                <path d="M20 0C8.96 0 0 8.96 0 20s8.96 20 20 20 20-8.96 20-20S31.04 0 20 0zm0 6c3.32 0 6 2.68 6 6s-2.68 6-6 6-6-2.68-6-6 2.68-6 6-6zm0 28.4c-5 0-9.42-2.56-12-6.44.06-3.98 8-6.16 12-6.16 3.98 0 11.94 2.18 12 6.16-2.58 3.88-7 6.44-12 6.44z" fill="#CCC" fill-rule="nonzero">
#                </path>
#               </svg>
#              </div>
#             </div>
#            </button>
#           </div>
#           <span class="user_avatar_toggle__arrow">
#            <svg class="arrow-icon down" enable-background="new 0 0 512 512" height="512px" preserveaspectratio="xMinYMin meet" version="1.1" viewbox="0 0 512 512" width="512px" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#             <g>
#              <g transform="translate(261.928932, 262.000000) rotate(45.000000) translate(-261.928932, -262.000000) translate(76.928932, 77.000000)">
#               <g>
#                <path d="M146.537,223.463l277.301,0c11.343,0,20.537,9.197,20.536,20.541l0.001, 30.81 c-0.001,11.345-9.197,20.541-20.539,20.541l-328.654,0c-5.671, 0-10.805-2.299-14.521-6.015 c-3.718-3.719-6.017-8.853-6.017-14.523l0-328.654c0.001-11.342, 9.197-20.538,20.541-20.539l30.809,0 c11.344,0,20.541,9.197,20.541,20.537l-0.001, 277.301L146.537,223.463z">
#                </path>
#               </g>
#               <g>
#                <path d="M146.537,223.463l277.301,0c11.343,0,20.537,9.197,20.536,20.541l0.001, 30.81 c-0.001,11.345-9.197,20.541-20.539,20.541l-328.654,0c-5.671, 0-10.805-2.299-14.521-6.015 c-3.718-3.719-6.017-8.853-6.017-14.523l0-328.654c0.001-11.342, 9.197-20.538,20.541-20.539l30.809,0 c11.344,0,20.541,9.197,20.541,20.537l-0.001, 277.301L146.537,223.463z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </svg>
#           </span>
#          </div>
#          <div class="toolbar__user-area__container header__fade-menu-dropdown">
#          </div>
#         </div>
#        </div>
#       </header>
#       <div class="application-controller__view">
#        <span class="application-controller__transition-container">
#         <div class="application-controller__content">
#          <div class="page-details-view page-details-view__only-title">
#           <div class="page-template">
#            <h1 class="view-title page-template__header">
#             Filmes
#            </h1>
#            <div class="offer-unit">
#             <div class="playkit-slider playkit-slider--6-4-2-cols">
#              <div class="playkit-container">
#               <section class="playkit-slider__header">
#                <h2 class="title conditional-title__title">
#                 Escolha pelo gênero
#                </h2>
#               </section>
#              </div>
#              <div class="playkit-slider__container">
#               <div class="playkit-list__prev playkit-list__prev--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__prev-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#               <div class="playkit-slider__content">
#                <div class="playkit-slider__track" style="-webkit-transform:translate(0%, 0);transform:translate(0%, 0)">
#                 <div class="playkit-slider__item">
#                  <a href="undefined" style="text-decoration:none" title="">
#                   <style data-emotion-css="1ultdaj-Box">
#                    .css-1ultdaj-Box{background-color:#242424;}
#                   </style>
#                   <div class="category-background css-1ultdaj-Box et03xv50">
#                    <picture class="category-background__image category-background__image--no-title css-7xzase-Image eoo3n7n0">
#                     <img alt="" src=""/>
#                    </picture>
#                    <style data-emotion-css="1ve8x7h-Text-StyledHeading">
#                     .css-1ve8x7h-Text-StyledHeading{font-weight:700;margin:0;color:#ffffff;font-family:"Open Sans",sans-serif;font-size:16px;}
#                    </style>
#                    <h4 class="category-background__title css-1ve8x7h-Text-StyledHeading e12witel0">
#                    </h4>
#                   </div>
#                  </a>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <a href="undefined" style="text-decoration:none" title="">
#                   <style data-emotion-css="1ultdaj-Box">
#                    .css-1ultdaj-Box{background-color:#242424;}
#                   </style>
#                   <div class="category-background css-1ultdaj-Box et03xv50">
#                    <picture class="category-background__image category-background__image--no-title css-7xzase-Image eoo3n7n0">
#                     <img alt="" src=""/>
#                    </picture>
#                    <style data-emotion-css="1ve8x7h-Text-StyledHeading">
#                     .css-1ve8x7h-Text-StyledHeading{font-weight:700;margin:0;color:#ffffff;font-family:"Open Sans",sans-serif;font-size:16px;}
#                    </style>
#                    <h4 class="category-background__title css-1ve8x7h-Text-StyledHeading e12witel0">
#                    </h4>
#                   </div>
#                  </a>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <a href="undefined" style="text-decoration:none" title="">
#                   <style data-emotion-css="1ultdaj-Box">
#                    .css-1ultdaj-Box{background-color:#242424;}
#                   </style>
#                   <div class="category-background css-1ultdaj-Box et03xv50">
#                    <picture class="category-background__image category-background__image--no-title css-7xzase-Image eoo3n7n0">
#                     <img alt="" src=""/>
#                    </picture>
#                    <style data-emotion-css="1ve8x7h-Text-StyledHeading">
#                     .css-1ve8x7h-Text-StyledHeading{font-weight:700;margin:0;color:#ffffff;font-family:"Open Sans",sans-serif;font-size:16px;}
#                    </style>
#                    <h4 class="category-background__title css-1ve8x7h-Text-StyledHeading e12witel0">
#                    </h4>
#                   </div>
#                  </a>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <a href="undefined" style="text-decoration:none" title="">
#                   <style data-emotion-css="1ultdaj-Box">
#                    .css-1ultdaj-Box{background-color:#242424;}
#                   </style>
#                   <div class="category-background css-1ultdaj-Box et03xv50">
#                    <picture class="category-background__image category-background__image--no-title css-7xzase-Image eoo3n7n0">
#                     <img alt="" src=""/>
#                    </picture>
#                    <style data-emotion-css="1ve8x7h-Text-StyledHeading">
#                     .css-1ve8x7h-Text-StyledHeading{font-weight:700;margin:0;color:#ffffff;font-family:"Open Sans",sans-serif;font-size:16px;}
#                    </style>
#                    <h4 class="category-background__title css-1ve8x7h-Text-StyledHeading e12witel0">
#                    </h4>
#                   </div>
#                  </a>
#                 </div>
#                </div>
#               </div>
#               <div class="playkit-list__next playkit-list__next--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__next-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor;transform:rotate(180deg);-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg)" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="offer-unit">
#             <div class="playkit-slider posters-offer playkit-slider--6-4-2-cols">
#              <div class="playkit-container">
#               <section class="playkit-slider__header">
#                <h2 class="title conditional-title__title">
#                 Grandes sucessos
#                </h2>
#               </section>
#              </div>
#              <div class="playkit-slider__container">
#               <div class="playkit-list__prev playkit-list__prev--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__prev-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#               <div class="playkit-slider__content">
#                <div class="playkit-slider__track" style="-webkit-transform:translate(0%, 0);transform:translate(0%, 0)">
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="playkit-list__next playkit-list__next--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__next-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor;transform:rotate(180deg);-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg)" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="offer-unit">
#             <div class="playkit-slider posters-offer playkit-slider--6-4-2-cols">
#              <div class="playkit-container">
#               <section class="playkit-slider__header">
#                <h2 class="title conditional-title__title">
#                 Novidades
#                </h2>
#               </section>
#              </div>
#              <div class="playkit-slider__container">
#               <div class="playkit-list__prev playkit-list__prev--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__prev-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#               <div class="playkit-slider__content">
#                <div class="playkit-slider__track" style="-webkit-transform:translate(0%, 0);transform:translate(0%, 0)">
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="playkit-list__next playkit-list__next--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__next-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor;transform:rotate(180deg);-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg)" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="offer-unit">
#             <div class="playkit-slider posters-offer playkit-slider--6-4-2-cols">
#              <div class="playkit-container">
#               <section class="playkit-slider__header">
#                <h2 class="title conditional-title__title">
#                 Mais assistidos
#                </h2>
#               </section>
#              </div>
#              <div class="playkit-slider__container">
#               <div class="playkit-list__prev playkit-list__prev--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__prev-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#               <div class="playkit-slider__content">
#                <div class="playkit-slider__track" style="-webkit-transform:translate(0%, 0);transform:translate(0%, 0)">
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="playkit-list__next playkit-list__next--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__next-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor;transform:rotate(180deg);-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg)" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="offer-unit">
#             <div class="playkit-slider posters-offer playkit-slider--6-4-2-cols">
#              <div class="playkit-container">
#               <section class="playkit-slider__header">
#                <a aria-label="Veja mais em Premiados" class="link-title conditional-title__link" href="/categorias/filmes-premiados/">
#                 <h2 class="title">
#                  Premiados
#                  <div class="link-title__call-to-action">
#                   <span>
#                    Veja mais
#                   </span>
#                   <span class="link-title__icon">
#                    <svg class="arrow-icon right" enable-background="new 0 0 512 512" height="512px" preserveaspectratio="xMinYMin meet" version="1.1" viewbox="0 0 512 512" width="512px" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                     <g>
# ...
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="playkit-list__next playkit-list__next--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__next-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor;transform:rotate(180deg);-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg)" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="offer-unit">
#             <div class="playkit-slider posters-offer playkit-slider--6-4-2-cols">
#              <div class="playkit-container">
#               <section class="playkit-slider__header">
#                <a aria-label="Veja mais em Todos os filmes" class="link-title conditional-title__link" href="/categorias/todos-os-filmes/">
#                 <h2 class="title">
#                  Todos os filmes
#                  <div class="link-title__call-to-action">
#                   <span>
#                    Veja mais
#                   </span>
#                   <span class="link-title__icon">
#                    <svg class="arrow-icon right" enable-background="new 0 0 512 512" height="512px" preserveaspectratio="xMinYMin meet" version="1.1" viewbox="0 0 512 512" width="512px" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                     <g>
#                      <g transform="translate(261.928932, 262.000000) rotate(45.000000) translate(-261.928932, -262.000000) translate(76.928932, 77.000000)">
#                       <g>
#                        <path d="M146.537,223.463l277.301,0c11.343,0,20.537,9.197,20.536,20.541l0.001, 30.81 c-0.001,11.345-9.197,20.541-20.539,20.541l-328.654,0c-5.671, 0-10.805-2.299-14.521-6.015 c-3.718-3.719-6.017-8.853-6.017-14.523l0-328.654c0.001-11.342, 9.197-20.538,20.541-20.539l30.809,0 c11.344,0,20.541,9.197,20.541,20.537l-0.001, 277.301L146.537,223.463z">
#                        </path>
#                       </g>
#                       <g>
#                        <path d="M146.537,223.463l277.301,0c11.343,0,20.537,9.197,20.536,20.541l0.001, 30.81 c-0.001,11.345-9.197,20.541-20.539,20.541l-328.654,0c-5.671, 0-10.805-2.299-14.521-6.015 c-3.718-3.719-6.017-8.853-6.017-14.523l0-328.654c0.001-11.342, 9.197-20.538,20.541-20.539l30.809,0 c11.344,0,20.541,9.197,20.541,20.537l-0.001, 277.301L146.537,223.463z">
#                        </path>
#                       </g>
#                      </g>
#                     </g>
#                    </svg>
#                   </span>
#                  </div>
#                 </h2>
#                </a>
#               </section>
#              </div>
#              <div class="playkit-slider__container">
#               <div class="playkit-list__prev playkit-list__prev--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__prev-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#               <div class="playkit-slider__content">
#                <div class="playkit-slider__track" style="-webkit-transform:translate(0%, 0);transform:translate(0%, 0)">
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                 <div class="playkit-slider__item">
#                  <div>
#                   <figure class="playkit-thumb__thumb-wrapper playkit-thumb__poster-thumb" style="text-align:left">
#                    <div class="playkit-thumb__thumb-placeholder" style="background-color:#242424;padding-top:148.06629834254144%">
#                    </div>
#                    <figcaption class="playkit-thumb__poster-caption" style="color:#242424;filter:invert(100%);font-family:'Open Sans', sans-serif">
#                    </figcaption>
#                   </figure>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="playkit-list__next playkit-list__next--disabled playkit-list__always-show-navigation">
#                <div class="playkit-list__next-icon">
#                 <svg style="width:100%;height:100%;fill:currentColor;transform:rotate(180deg);-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg)" version="1.1" viewbox="0 0 24 24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
#                  <g fill="none" fill-rule="evenodd">
#                   <path d="M0 0h24v24H0z">
#                   </path>
#                   <path d="M15.41 16.59L10.83 12l4.58-4.59L14 6l-6 6 6 6z" fill="currentColor">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </span>
#       </div>
#       <footer class="footer-widget">
#        <div class="footer-widget--short grid">
#         <p class="footer-widget__text">
#          ©
#          <!-- -->
#          2022
#          <!-- -->
#          Globo Comunicação e Participações S.A.
#         </p>
#         <p class="footer-widget__text">
#          Todos os direitos reservados -
#          <a aria-label="Ir para termos e políticas de uso" class="footer-widget__link footer-widget__terms-link" href="https://globoplay.globo.com/termosepoliticas/" rel="noopener noreferrer" target="_blank">
#           Termos e políticas
#          </a>
#         </p>
#        </div>
#        <div class="footer-widget--long grid">
#         Globo.com © 2000-
#         <!-- -->
#         2022
#         <!-- -->
#         Globo Comunicação e Participações S.A. - Todos os direitos reservados
#         <a aria-label="Ir para termos e políticas de uso" class="footer-widget__link footer-widget__terms-link" href="https://globoplay.globo.com/termosepoliticas/" rel="noopener noreferrer" target="_blank">
#          Termos e políticas
#         </a>
#        </div>
#       </footer>
#      </div>
#      <span>
#       <div aria-hidden="true" class="toast">
#        <div class="toast__content">
#         <div class="toast__content__buttons">
#          <div class="playkit-buttons__button playkit-buttons__colored-button toast__content__buttons__close playkit-buttons__colored-button--with-hover" role="button" style="font-family:'Open Sans', sans-serif;border-color:#f31d1d;background-color:#ffffff;color:#000000">
#           <div class="playkit-buttons__button-content">
#            <span class="playkit-buttons__button--upperCase">
#             Ok, entendi
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </span>
#      <div style="position:fixed;z-index:9999;top:16px;left:16px;right:16px;bottom:16px;pointer-events:none">
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="application/javascript">
#    // Quicksilver global variables var Quicksilver = { version: "3.499.2", node: document.getElementById('app'), tenant: "globo-play", state: {"status":200,"data":{"view":{"data":{}}}}, apolloState: {"ROOT_QUERY":{"__typename":"Query","categories({\"parentCategoryId\":null})":{"__typename":"CategoryCollection","resources":[{"__typename":"Category","name":"Novelas","background":"https:\u002F\u002Fs2.glbimg.com\u002FpXK8P-i2al-_PsXnewCUjLJhPaA=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002F5U_D6lyQdJZNMHo-wRiaZQpo02A=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002Fj\u002Fa\u002FXoYMQyR2aVCVffn3dnvg\u002F2021-2374-imagens-categoria-novelas.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"novelas"}},{"__typename":"Category","name":"Séries","background":"https:\u002F\u002Fs2.glbimg.com\u002FpqiaoRDkN5oAbQiPGQAXbkcjgnc=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002FSazIWlUPj5F1QHPxyKAymFpoz6M=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002Fn\u002FR\u002FYWVvMsTGAExLiAtE6g1g\u002F2021-2525-aruanas-categorias.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"series"}},{"__typename":"Category","name":"Filmes","background":"https:\u002F\u002Fs2.glbimg.com\u002F31AApeFc__1aEca_E7yHNtVq108=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002FsJGqNvry9akX36sSMj4QATwKsyc=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002Fq\u002Fx\u002F9jTPrhRWO37Hm71QLUXQ\u002F2021-2525-marighella-categorias.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"filmes"}},{"__typename":"Category","name":"Infantil","background":"https:\u002F\u002Fs2.glbimg.com\u002FQa_9uD9iYvpsN2gjufcOwA-AYlA=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002FxvqMID3eAWkPVxsfuX7x20-8-tc=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002FW\u002FT\u002FLZcZ0qS1qIM3abcFlEQQ\u002F2021-2374-imagens-categoria-infantil.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"infantil"}},{"__typename":"Category","name":"Realities","background":"https:\u002F\u002Fs2.glbimg.com\u002FaAR_biKZzTKOVfTrizggghrrbpc=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002FNrcnucpeyQwIcKDSvfNL5v-dNbo=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002Fi\u002F5\u002Fq5mgEVRE6vrkXZlJveRQ\u002F2021-2374-imagens-categoria-realities.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"reality-shows"}},{"__typename":"Category","name":"Documentários","background":"https:\u002F\u002Fs2.glbimg.com\u002FcLcoHMAUFs4vH0YLZkfRSPbHFmA=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002FwpK7IuzWu51TkoMgSHXi1w4eTcs=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002Fw\u002FL\u002FfAEfxQRQiiOWpxgMDsoQ\u002F2021-2525-gill-na-california-categorias.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"documentarios"}},{"__typename":"Category","name":"Variedades","background":"https:\u002F\u002Fs2.glbimg.com\u002FL1SMgWoVeHpf0pc9lpE7UiC7eYY=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002Ft6n1hDw3HlqqiPUNMp_MMnLDH6Q=\u002Fhttps:\u002F\u002Fi.s3.glbimg.com\u002Fv1\u002FAUTH_c3c606ff68e7478091d1ca496f9c5625\u002Finternal_photos\u002Fbs\u002F2021\u002Fg\u002Fr\u002F9fLA2KSEGsq7fZMjM9IQ\u002Fcategoria-variedades.jpg","navigation":{"__typename":"MenuPageNavigation","identifier":"variedades"}},{"__typename":"Category","name":"Humor","background":"https:\u002F\u002Fs2.glbimg.com\u002FCMILsKEV4INylrro1WdEpBY8AQE=\u002F0x196\u002Fhttps:\u002F\u002Fs2.glbimg.com\u002Fac-YvybSlMv17xbva9PfJh6b7PE=\u002Fhttps:\u002F\u002Fi ...
#   </script>
#   <script>
#    (function(sa,fbc){function load(f,c){var a=document.createElement('script'); a.async=1;a.src=f;var s=document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(a,s);}load(sa); window.addEventListener('load',function(){firebase.initializeApp(fbc).performance()}); })('https://www.gstatic.com/firebasejs/8.3.1/firebase-performance-standalone.js', { apiKey: "AIzaSyDG7rYcDhj2mMqURfs_IXgZXHFDE8Mpcwc", authDomain: "globo-play.firebaseapp.com", databaseURL: "https://globo-play.firebaseio.com", projectId: "globo-play", storageBucket: "globo-play.appspot.com", messagingSenderId: "846115935537", appId: "1:846115935537:web:b0fe324ed14e8410", measurementId: "G-WPDK1YFMPF" });
#   </script>
#  </body>
# </html>
